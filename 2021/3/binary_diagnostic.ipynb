# %%
with open("input.txt") as f:
    raw_report = f.read()

# %%
diagnostic_report = raw_report.split()
diagnostic_report
# Out:
# ['010000010010',
#  '011001011100',
#  '110011011101',
#  '110100100001',
#  '000110011110',
#  '110101000101',
#  '100110111001',
#  '110000000000',
#  '100101100111',
#  '001001011000',
#  '010010011010',
#  '001110111000',
#  '001011111010',
#  '110010111011',
#  '001001010101',
#  '111111011111',
#  '101001001110',
#  '011001000101',
#  '001001111100',
#  '000101110000',
#  '101000101101',
#  '101000011101',
#  '011011001111',
#  '010100011001',
#  '100010001000',
#  '100010111010',
#  '000110101100',
#  '100101010111',
#  '110111101111',
#  '011101111001',
#  '111001110110',
#  '101101000000',
#  '010010111101',
#  '111101111101',
#  '010000001110',
#  '000111111001',
#  '010111100101',
#  '011101100000',
#  '001011011111',
#  '111010000110',
#  '111010001001',
#  '000000010111',
#  '001110011110',
#  '100011100010',
#  '111110010111',
#  '100111111111',
#  '100000011011',
#  '000110111101',
#  '010100010111',
#  '110000011111',
#  '011011011001',
#  '101110011100',
# ...

# %%
len(diagnostic_report)
# Out:
# 1000

# %%
diagnostic_report[0]
# Out:
# '010000010010'

# %%
int_diagnostic_report = [int(number, base=2) for number in diagnostic_report]
out = int_diagnostic_report[0]
for number in int_diagnostic_report[1:]: 
    out = out | number
out
# Out:
# 4095

# %%
~4095 & 0xffff
# Out:
# 61440

# %%
4095*61440
# Out:
# 251596800

# %%
bin(-5)
# Out:
# '-0b101'

# %%
~4
# Out:
# -5
